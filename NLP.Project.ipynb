# %% [markdown]
# # Healthcare Urgency Classification Using Natural Language Processing

# %%
import pandas as pd
import string
import pandas as pd
# !pip install nltk
import re
from nltk.corpus import stopwords
import nltk
from nltk.tokenize import word_tokenize
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# Requirement already satisfied: nltk in c:\users\razan\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\razan\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\razan\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\razan\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\razan\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\razan\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\razan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\razan\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\razan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\razan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\razan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
#import dataset 

df = pd.read_csv("dataset.csv", sep=';')
print(df.columns)
df.head()
# Out:
# Index(['text', 'label'], dtype='object')
#                                                 text       label
# 0  severe abdominal pain huardign and rebound ten...      URGENT
# 1  laceartion to forearm requiring sutures bleedi...      URGENT
# 2  no acute distress here perop for evaluation su...     ROUTINE
# 3  followup for stable eczema no new zomplaints. ...  NON-URGENT
# 4  patient anaphylaxis airway swellign and hypote...   EMERGENCY

# %%
df["original_text"] = df["text"]

# %%
# Example Before Cleaning:
print("Before Cleaning:\n")
print(df["original_text"].iloc[6])
# Out:
# Before Cleaning:
#
# high fever and vomiting persistent for days signs of uehydration,URGENT

# %%
#Converting Text to Lowercase:

df["text"] = df["text"].str.lower()
df["text"].iloc[4]

#Removing Punctuation from Text:

df["text"] = df["text"].apply(lambda x: x.translate(str.maketrans("", "", string.punctuation)))
df["text"].iloc[2]

#Text Cleaning: Lowercasing and Removing Punctuation:

df["cleaned"] =df["text"].str.lower().apply(lambda x: x.translate(str.maketrans("", "", string.punctuation)))

df[["text", "cleaned"]].head(3)


#Example After Cleaning:
print("\nAfter Cleaning:\n")
print(df["text"].iloc[6])
# Out:
# After Cleaning:
#
# high fever and vomiting persistent for days signs of uehydrationurgent

# %%
# Example Before Tokens:
print("Example before tokns:")
print(df['text'].iloc[0])
# Out:
# Example before tokns:
# severe abdominal pain huardign and rebound tenderness on exam unclear onseturgent

# %%
#Loading English Stopwords:

stop_words = set(stopwords.words('english'))

# Selecting a Text Sample from the Dataset
text = df['text'].iloc[0]

#Text Cleaning, Tokenization, and Stopword Removal:

text_clean = text.lower()
text_clean = re.sub(r'[^a-z\s]', '', text_clean)
tokens = [word for word in text_clean.split() if word not in stop_words]

#Example After Tokns:
print("Example after tokns:")
print(' '.join(tokens))

df.head()
# Out:
# Example after tokns:
# severe abdominal pain huardign rebound tenderness exam unclear onseturgent
#                                                 text       label  \
# 0  severe abdominal pain huardign and rebound ten...      URGENT
# 1  laceartion to forearm requiring sutures bleedi...      URGENT
# 2  no acute distress here perop for evaluation su...     ROUTINE
# 3  followup for stable eczema no new zomplaints m...  NON-URGENT
# 4  patient anaphylaxis airway swellign and hypote...   EMERGENCY
#
#                                        original_text  \
# 0  severe abdominal pain huardign and rebound ten...
# 1  laceartion to forearm requiring sutures bleedi...
# 2  no acute distress here perop for evaluation su...
# 3  followup for stable eczema no new zomplaints. ...
# 4  patient anaphylaxis airway swellign and hypote...
#
#                                              cleaned
# 0  severe abdominal pain huardign and rebound ten...
# 1  laceartion to forearm requiring sutures bleedi...
# 2  no acute distress here perop for evaluation su...
# 3  followup for stable eczema no new zomplaints m...
# 4  patient anaphylaxis airway swellign and hypote...

# %%
#Example Before Stopwords Removal:

print("Before Stopwords Removal:\n")
print(df["text"].iloc[0])
# Out:
# Before Stopwords Removal:
#
# severe abdominal pain huardign and rebound tenderness on exam unclear onseturgent

# %%
#Removing Stopwords

def remove_stopwords(text):

    words = word_tokenize(text)

    filtered_words = [word for word in words if word.lower() not in stop_words]

    return " ".join(filtered_words)

df.columns

df["clean_text"] = df["text"].apply(remove_stopwords)

#Example After Stopwords Removal:
 
print("\nAfter Stopwords Removal:\n")
print(df["clean_text"].iloc[0])
# Out:
# After Stopwords Removal:
#
# severe abdominal pain huardign rebound tenderness exam unclear onseturgent

# %%
#Example Before Lemmatization:

print("Before Lemmatization:\n")
print(df["clean_text"].iloc[6])
# Out:
# Before Lemmatization:
#
# high fever vomiting persistent days signs uehydrationurgent

# %%
#Applying Lemmatization to Normalize Words:

lemmatizer = WordNetLemmatizer()

def lemmatize_text(text):
    
    words = word_tokenize(text)
    
    lemmas = [lemmatizer.lemmatize(word) for word in words]
    
    return " ".join(lemmas)

df["lemmatized_text"] = df["clean_text"].apply(lemmatize_text)

#Example After Lemmatization:

print("\nAfter Lemmatization:\n")
print(df["lemmatized_text"].iloc[6])
# Out:
# After Lemmatization:
#
# high fever vomiting persistent day sign uehydrationurgent
